# %%
import utils.prepare_dataset as predat
import matplotlib.pyplot as plt

# %%
ds,dsc = predat.prepare_dataset()
# Out:
# There are 17875 cloud masks in the directory
# There are 10179 cloud masks between 0 and 25 percent of coverage
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds,dsc = predat.prepare_dataset()
#
# File ~/cloud-ML-data-recovery/utils/prepare_dataset.py:96, in prepare_dataset(sen3_path_str, cloud_path_str, low_bound, high_bound, num_samples, num_clouds)
#      94 clouds_path = os.path.join(cloud_path_str)
#      95 clouds_list = filter_masks_by_percentage(clouds_path, low_bound, high_bound, num_clouds)
# ---> 96 clouds = fetch_cloud_masks(clouds_path, clouds_list)
#      98 sen3_list = list_sen3(sen3_path)
#      99 sen3_list_reduced = random.sample(sen3_list, num_samples)
#
# File ~/cloud-ML-data-recovery/utils/prepare_dataset.py:44, in fetch_cloud_masks(clouds_path, file_list)
#      42 tens = np.load(os.path.join(clouds_path,file_list[0]))[:,:,np.newaxis]
#      43 for f in file_list[1:]:
# ---> 44     tens = np.concatenate([tens,np.load(os.path.join(clouds_path,f))[:,:,np.newaxis]],axis=2)
#      45 return tens
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:434, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     432 _ZIP_SUFFIX = b'PK\x05\x06' # empty zip files start with this
#     433 N = len(format.MAGIC_PREFIX)
# --> 434 magic = fid.read(N)
#     435 if not magic:
#     436     raise EOFError("No data left in file")
#
# KeyboardInterrupt:

# %%
for i in range(1,13):
    plt.subplot(4,6,2*i-1)
    plt.imshow(ds["Oa01_reflectance"][i])
    plt.subplot(4,6,2*i)
    plt.imshow(dsc["Oa01_reflectance"][i])
